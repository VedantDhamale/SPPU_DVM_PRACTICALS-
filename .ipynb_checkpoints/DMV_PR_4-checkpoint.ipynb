# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df= pd.read_csv("Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK   Coomee       1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df['total_sqft']=pd.to_numeric(df["total_sqft"],errors='coerce')
df['balcony']=pd.to_numeric(df["balcony"],errors='coerce')

# %%
df['Price_per_sqft']=df['price']/df['total_sqft']

# %%
def category_size(total_sqft):
    if total_sqft<500:
        return 'small'
    elif total_sqft >= 500 and total_sqft<=1500:
        return 'medium' 
    else:
        return 'Larger'

df['Size_Category']=df['total_sqft'].apply(category_size)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society  total_sqft  bath  balcony   price  Price_per_sqft  \
# 0          2 BHK   Coomee      1056.0   2.0      1.0   39.07        0.036998
# 1      4 Bedroom  Theanmp      2600.0   5.0      3.0  120.00        0.046154
# 2          3 BHK      NaN      1440.0   2.0      3.0   62.00        0.043056
# 3          3 BHK  Soiewre      1521.0   3.0      1.0   95.00        0.062459
# 4          2 BHK      NaN      1200.0   2.0      1.0   51.00        0.042500
# ...          ...      ...         ...   ...      ...     ...             ...
# 13315  5 Bedroom  ArsiaEx      3453.0   4.0      0.0  231.00        0.066898
# 13316      4 BHK      NaN      3600.0   5.0      NaN  400.00        0.111111
# 13317      2 BHK  Mahla T      1141.0   2.0      1.0   60.00        0.052585
# 13318      4 BHK  SollyCl      4689.0   4.0      1.0  488.00        0.104073
# 13319      1 BHK      NaN       550.0   1.0      1.0   17.00        0.030909
#
#       Size_Category
# 0            medium
# 1            Larger
# 2            medium
# 3            Larger
# 4            medium
# ...             ...
# 13315        Larger
# 13316        Larger
# 13317        medium
# 13318        Larger
# 13319        medium
#
# [13320 rows x 11 columns]

# %%
missing_values= df.isnull().sum()
missing_values
# Out:
# area_type            0
# availability         0
# location             1
# size                16
# society           5502
# total_sqft         247
# bath                73
# balcony            609
# price                0
# Price_per_sqft     247
# Size_Category        0
# dtype: int64

# %%
df.drop('society',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'total_sqft', 'bath',
#        'balcony', 'price', 'Price_per_sqft', 'Size_Category'],
#       dtype='object')

# %%
df['balcony']=df['balcony'].fillna(1)

# %%
df.dropna(inplace=True)

# %%
missing_Values=df.isnull().sum()
missing_Values
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# total_sqft        0
# bath              0
# balcony           0
# price             0
# Price_per_sqft    0
# Size_Category     0
# dtype: int64

# %%
cat_col=df.select_dtypes(include=['object']).columns
print(cat_col)
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'Size_Category'], dtype='object')

# %%
print(df['area_type'].unique())
# Out:
# ['Super built-up  Area' 'Plot  Area' 'Built-up  Area' 'Carpet  Area']

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for col in cat_col:
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#        area_type  availability  location  size  total_sqft  bath  balcony  \
# 0              3            40       402    13      1056.0   2.0      1.0
# 1              2            79       300    19      2600.0   5.0      3.0
# 2              0            79      1160    16      1440.0   2.0      3.0
# 3              3            79       739    16      1521.0   3.0      1.0
# 4              3            79       698    13      1200.0   2.0      1.0
# ...          ...           ...       ...   ...         ...   ...      ...
# 13315          0            79      1233    22      3453.0   4.0      0.0
# 13316          3            79       985    18      3600.0   5.0      1.0
# 13317          0            79       953    13      1141.0   2.0      1.0
# 13318          3            32       888    18      4689.0   4.0      1.0
# 13319          3            79       379     0       550.0   1.0      1.0
#
#         price  Price_per_sqft  Size_Category
# 0       39.07        0.036998              1
# 1      120.00        0.046154              0
# 2       62.00        0.043056              1
# 3       95.00        0.062459              0
# 4       51.00        0.042500              1
# ...       ...             ...            ...
# 13315  231.00        0.066898              0
# 13316  400.00        0.111111              0
# 13317   60.00        0.052585              1
# 13318  488.00        0.104073              0
# 13319   17.00        0.030909              1
#
# [13056 rows x 10 columns]

# %%
unique_counts=df.nunique()
print(unique_counts)


plt.figure(figsize=(6,4))
sns.barplot(x=unique_counts.index,y=unique_counts.values,palette='viridis')


plt.xticks(rotation=45)
plt.show()
# Out:
# area_type            4
# availability        80
# location          1287
# size                31
# total_sqft        1894
# bath                19
# balcony              4
# price             1838
# Price_per_sqft    7425
# Size_Category        3
# dtype: int64
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26048\2607339777.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=unique_counts.index,y=unique_counts.values,palette='viridis')

# %%
df1.groupby('area_type')['price'].max()
# Out:
# area_type
# Built-up  Area          2050.0
# Carpet  Area             500.0
# Plot  Area              3600.0
# Super built-up  Area    2912.0
# Name: price, dtype: float64

# %%
df1.groupby('size')['price'].max()
# Out:
# size
# 1 BHK          750.0
# 1 Bedroom      306.0
# 1 RK            52.0
# 10 BHK         525.0
# 10 Bedroom    3600.0
# 11 BHK         360.0
# 11 Bedroom     170.0
# 12 Bedroom     300.0
# 13 BHK         275.0
# 14 BHK         125.0
# 16 BHK         550.0
# 18 Bedroom     200.0
# 19 BHK         490.0
# 2 BHK          475.0
# 2 Bedroom      650.0
# 27 BHK         230.0
# 3 BHK         1015.0
# 3 Bedroom     2000.0
# 4 BHK         2912.0
# 4 Bedroom     2600.0
# 43 Bedroom     660.0
# 5 BHK         2700.0
# 5 Bedroom     2736.0
# 6 BHK         1000.0
# 6 Bedroom     2800.0
# 7 BHK         2200.0
# 7 Bedroom      972.0
# 8 BHK          310.0
# 8 Bedroom     1900.0
# 9 BHK          500.0
# 9 Bedroom     1200.0
# Name: price, dtype: float64

# %%
df1.groupby('location')['price'].max()
# Out:
# location
# 1 Annasandrapalya                                  150.00
# 1 Giri Nagar                                       360.00
# 1 Immadihalli                                      150.00
# 1 Ramamurthy Nagar                                 170.00
# 12th cross srinivas nagar banshankari 3rd stage    200.00
#                                                     ...
# t.c palya                                          160.00
# tc.palya                                            78.00
# vinayakanagar                                      200.00
# white field,kadugodi                               275.00
# whitefiled                                          32.73
# Name: price, Length: 1287, dtype: float64
